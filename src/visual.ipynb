# %%
# built in 
import os
import json
import glob

# custom modules
from nl_case_analyzer.visualizer import Visualizer

# %% [markdown]
# ###  Loading in Results

# %%
output_dir = r"/home/wibo_rag/nl-case-analyzer/results"

# %%
results_file_path = glob.glob(os.path.join(output_dir, "*.json"))
result_list = []

for file in results_file_path:
    with open(file, 'r', encoding='utf-8') as f:
                    data = json.load(f)
                    result_list.extend(data)

# %%
len(result_list)
# Out:
# 950

# %% [markdown]
# ## Visualize

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from nl_case_analyzer.visualizer import Visualizer
visualizer = Visualizer(result_list, output_dir)

# %%
df = visualizer._prepare_data()
df.head()
# Out:
#   sleutelfiguur            label value crypto_relevant
# 0       Rechter  betrouwbaarheid    ja              Ja
# 1       Rechter   rechtmatigheid    ja              Ja
# 2       Rechter      overtuigend    ja              Ja
# 3   Verdediging  betrouwbaarheid   nee              Ja
# 4   Verdediging   rechtmatigheid   nvt              Ja

# %%
visualizer.display_plots()
# Out:
# Displayed plot for sleutelfiguur_1
# Displayed plot for sleutelfiguur_2
# Displayed plot for sleutelfiguur_3

# %%
visualizer.save_plots()
# Out:
# No data available for sleutelfiguur: sleutelfiguur_1
# No data available for sleutelfiguur: sleutelfiguur_2
# No data available for sleutelfiguur: sleutelfiguur_3
